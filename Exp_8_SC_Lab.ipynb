# %% [markdown]
# <a href="https://colab.research.google.com/github/francojoem/Scientific-Computing-Lab/blob/main/Exp_8_SC_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 8.1 - Realize the vector t = [0, 100] with an increment of 0.01 and keep T = 20. Realize the following Fourier series. Plot the first 3 or 4 terms on the same graphic window and understand how the smooth sinusoids add up to a discontinuous square function.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
T=20
t = np.arange(0, 100, 0.01) # arguments: start, stop, step
n=1
y1 = ((-1)**n)*1/(2*n+1)*np.cos(2*math.pi*(2*n+1)*t/T)
n=2
y2 = ((-1)**n)*1/(2*n+1)*np.cos(2*math.pi*(2*n+1)*t/T)
n=3
y3 = ((-1)**n)*1/(2*n+1)*np.cos(2*math.pi*(2*n+1)*t/T)
y =(4/math.pi)*(1+y1+y2+y3)
fig,a = plt.subplots(4,1)
a[0].plot(t,y1)
a[0].set_title('First term')
a[1].plot(t,y2)
a[1].set_title('Second term')
a[2].plot(t,y3)
a[2].set_title('Third term')
a[3].plot(t,y)
a[3].set_title('y')
plt.subplots_adjust(wspace=0.9,hspace=0.5,left=0.05,right=1.5,top=2,bottom=0.1)
plt.show()

# %% [markdown]
# 8.2 - Compute and plot the series for the first 10, 20, 50 and 100 terms and understand the lack of convergence at the points of discontinuity.

# %%
 
import numpy as np
import matplotlib.pyplot as plt
import math
T=20
t = np.arange(0, 100, 0.01) # arguments: start, stop, step
N=[10,20,50,100]
fig,a = plt.subplots(4,1)
i=0
for value in N:
  sum=1
  for n in range(1, value):
    term = ((-1)**n)*1/(2*n+1)*np.cos(2*math.pi*(2*n+1)*t/T)
    sum=sum+term
  y =(4/math.pi)*(1+sum)
  a[i].plot(t,y)
  a[i].set_title('y')
  i+=1
 
plt.subplots_adjust(wspace=0.9,hspace=0.5,left=0.05,right=1.5,top=2,bottom=0.1)
plt.show()

# %% [markdown]
# 8.3 - Consider the Fourier series:
# With t made a zero vector, f(0) = 1, resulting in the Madhava series for a as
# Use this to computer for the first 10, 20, 50 and 100 terms.

# %%
 
import math
T=20
N=[10,20,50,100]
i=0
for value in N:
	sum=1
	for n in range(1, value):
		term = ((-1)**n)*1/(2*n+1)
		sum=sum+term
	pi_value =4*sum
	print(pi_value)
	i+=1
# Out:
# 3.0418396189294032
# 3.09162380666784
# 3.121594652591011
# 3.1315929035585537
